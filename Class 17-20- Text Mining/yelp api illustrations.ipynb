# %% [markdown]
# <h1>Yelp API</h1>
# <li>https://www.yelp.com/developers/documentation/v3
# <li>log into yelp (top right hand corner of the page)
# <li>Click <span style="color:blue">Create App</span> on the left hand menu bar
# <li>Enter app info (leave optional stuff blank)
# <li>Copy the client id and client secret to a secure place (this notebook should do the trick or use a text file!)

# %%
CLIENT_ID = ""
API_KEY = ""

# %%
with open('/Users/hardeepjohar/Documents/Courses/Fall2018/API_KEYS/yelp_fusion.txt','r') as f:
    count = 0
    for line in f:
        if count == 0:
            CLIENT_ID = line.strip()
        if count == 1:
            API_KEY = line.strip()
        count+=1

# %%
print(CLIENT_ID,API_KEY)

# %%
# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com' #The API url header
SEARCH_PATH = '/v3/businesses/search' #The path for an API request to find businesses
BUSINESS_PATH = '/v3/businesses/'  # The path to get data for a single business

# %% [markdown]
# <h3>Now we can get reviews</h3>
# <li>get_reviews(location,number=15) returns the reviews of "number" (default=15) restaurants in the vicinity of "location"
# <li>First, we'll write a function that gets  restaurants in the vicinity of location

# %%
def get_restaurants(api_key,location,number=15):
    import requests
    
    #First we get the access token
    #Set up the search data dictionary
    search_data = {
    'term': "restaurant",
    'location': location.replace(' ', '+'),
    'limit': number
    }
    url = API_HOST + SEARCH_PATH
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }
    response = requests.request('GET', url, headers=headers, params=search_data).json()
    businesses = response.get('businesses')
    return businesses

# %%
get_restaurants(API_KEY,"Columbia University, New York, NY")
# Out:
# [{'alias': 'flat-top-new-york',
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 40.810041, 'longitude': -73.958693},
#   'display_phone': '(646) 820-7735',
#   'distance': 424.3853457755761,
#   'id': 'E2mNgb479B3BCfwi2G_KdQ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/y2YlqtpKU2tciozvngNbsg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1241 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['1241 Amsterdam Ave', 'New York, NY 10027'],
#    'state': 'NY',
#    'zip_code': '10027'},
#   'name': 'Flat Top',
#   'phone': '+16468207735',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 391,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/flat-top-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'dun-huang-new-york-3',
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'coordinates': {'latitude': 40.81106, 'longitude': -73.95818},
#   'display_phone': '(646) 476-4549',
#   'distance': 529.7785887922937,
#   'id': 'cGSLzPA_SCWrN3cyT86Nhw',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DJccPh3GccNPXvK_LrWbtg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1268 Amsterdam Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['1268 Amsterdam Ave', 'New York, NY 10027'],
#    'state': 'NY',
#    'zip_code': '10027'},
#   'name': 'Dun Huang',
#   'phone': '+16464764549',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 34,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/dun-huang-new-york-3?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'es-bar-new-york-3',
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'coordinates': {'latitude': 40.80554, 'longitude': -73.96539},
#   'display_phone': '(212) 877-0961',
#   'distance': 313.6201806208238,
#   'id': 'DybR3L6G9zVTQ1eeP0hG_g',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oL3dyRx7PEpYvXTKNy9cGg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2888 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['2888 Broadway', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': "e's BAR",
#   'phone': '+12128770961',
#   'rating': 4.5,
#   'review_count': 6,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/es-bar-new-york-3?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'lolos-seafood-shack-new-york',
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'coordinates': {'latitude': 40.80486, 'longitude': -73.95567},
#   'display_phone': '(646) 649-3356',
#   'distance': 651.2070570437573,
#   'id': 'XOnspIaW6mYVmrvgqOaYSQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KPT7UUYDhCSfs1E8NUfeKw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '303 W 116th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['303 W 116th St', 'New York, NY 10026'],
#    'state': 'NY',
#    'zip_code': '10026'},
#   'name': "Lolo's Seafood Shack",
#   'phone': '+16466493356',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 564,
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/lolos-seafood-shack-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'thai-market-new-york',
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'coordinates': {'latitude': 40.80132, 'longitude': -73.96529},
#   'display_phone': '(212) 280-4575',
#   'distance': 729.8529299525782,
#   'id': 'p2zm0HnXZkI2yCAuYLb45g',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jPGJaYsRiU_se_UJzphxkQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '960 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['960 Amsterdam Ave', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': 'Thai Market',
#   'phone': '+12122804575',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 897,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/thai-market-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'friedmans-new-york-62',
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 40.80829, 'longitude': -73.95977},
#   'display_phone': '(212) 932-0600',
#   'distance': 246.57143174690665,
#   'id': 'uTS2GevPXqsFKMgdpp5Txw',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pfIqvvNLdhR9kE1fjqylvg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1187 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['1187 Amsterdam Ave', 'New York, NY 10027'],
#    'state': 'NY',
#    'zip_code': '10027'},
#   'name': "Friedman's",
#   'phone': '+12129320600',
#   'price': '$$',
#   'rating': 3.5,
#   'review_count': 274,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/friedmans-new-york-62?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'saiguette-new-york',
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'coordinates': {'latitude': 40.79902, 'longitude': -73.96281},
#   'display_phone': '(212) 866-6888',
#   'distance': 953.8624575721236,
#   'id': 'sKIYGvENchifk1YwFe77pA',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CGSy1Ni2iaxYuTq3QuWEgg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '935 Columbus Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['935 Columbus Ave', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': 'Saiguette',
#   'phone': '+12128666888',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 510,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/saiguette-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'dig-inn-new-york-14',
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'coordinates': {'latitude': 40.8055649, 'longitude': -73.9653549},
#   'display_phone': '(212) 776-4047',
#   'distance': 325.51731156358824,
#   'id': 'GoHiAkblJb7mqFEiD8T62g',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GUm5PEKC2lfQR9PaoOZz7Q/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2884 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['2884 Broadway', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': 'Dig Inn',
#   'phone': '+12127764047',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 274,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/dig-inn-new-york-14?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'mokja-new-york-3',
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'coordinates': {'latitude': 40.797744938993, 'longitude': -73.9678908884525},
#   'display_phone': '(646) 964-4296',
#   'distance': 1181.8171452453253,
#   'id': '6fYGuJZXiFb282D1qJzWSQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ElSyQlZdu4O84Sp6j89oLg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '852 Amsterdam',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['852 Amsterdam', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': 'Mokja',
#   'phone': '+16469644296',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 118,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/mokja-new-york-3?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'jin-ramen-west-harlem-new-york',
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'coordinates': {'latitude': 40.8154774, 'longitude': -73.9587672},
#   'display_phone': '(646) 559-2862',
#   'distance': 934.7251103137451,
#   'id': 'Pfjb9Rn5Th7R-pLXVARwlA',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k-jRBnEZkITJ1mZBMmGFrw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3183 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['3183 Broadway', 'New York, NY 10027'],
#    'state': 'NY',
#    'zip_code': '10027'},
#   'name': 'Jin Ramen - West Harlem',
#   'phone': '+16465592862',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 967,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/jin-ramen-west-harlem-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'marlow-bistro-new-york',
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'coordinates': {'latitude': 40.8028109023738,
#    'longitude': -73.9641991912535},
#   'display_phone': '(212) 662-9020',
#   'distance': 547.384365435194,
#   'id': 'MdFV5IBcX-Ni6I4Zy1EqIw',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-t5ApW-QyN6043o3i2gdUQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1018 Amsterdam Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['1018 Amsterdam Ave', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': 'Marlow Bistro',
#   'phone': '+12126629020',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 207,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/marlow-bistro-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'pisticci-new-york',
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 40.8141624, 'longitude': -73.960288},
#   'display_phone': '(212) 932-3500',
#   'distance': 776.1804413075187,
#   'id': 'wZkZmjZEJDraLJgAalnHvA',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AiMEHqj5x2lkPvdXe27HFw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '125 La Salle St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['125 La Salle St', 'New York, NY 10027'],
#    'state': 'NY',
#    'zip_code': '10027'},
#   'name': 'Pisticci',
#   'phone': '+12129323500',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 747,
#   'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/pisticci-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'red-hot-hot-pot-new-york',
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'coordinates': {'latitude': 40.8014032, 'longitude': -73.9615043},
#   'display_phone': '(646) 998-3337',
#   'distance': 676.0163533393259,
#   'id': '4zuvAX0g_h_vBgE34oALhg',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MA6Flql-o0wbVl6mA21tMg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1000 Columbus Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['1000 Columbus Ave', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': 'Red Hot Hot Pot',
#   'phone': '+16469983337',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 44,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/red-hot-hot-pot-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'kalbi-new-york',
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'coordinates': {'latitude': 40.8088083994982,
#    'longitude': -73.9631333202124},
#   'display_phone': '(646) 287-0262',
#   'distance': 146.60515332206535,
#   'id': '1CY0Mk1PXIUoVLsLhPq75A',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QmgdTPR3OUbAnY5H931Chg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '117TH ST & BROADWAY',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['117TH ST & BROADWAY', 'New York, NY 10026'],
#    'state': 'NY',
#    'zip_code': '10026'},
#   'name': 'KALBI',
#   'phone': '+16462870262',
#   'rating': 5.0,
#   'review_count': 4,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/kalbi-new-york?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'},
#  {'alias': 'mekong-new-york-2',
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'coordinates': {'latitude': 40.7984, 'longitude': -73.96326},
#   'display_phone': '(646) 678-3136',
#   'distance': 1023.3353552995227,
#   'id': 'MD-GiizNpmFbuDIdKGzXnA',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FYvDn8ZN-7xxjKB_U50pCA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '917 Columbus Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['917 Columbus Ave', 'New York, NY 10025'],
#    'state': 'NY',
#    'zip_code': '10025'},
#   'name': 'Mekong',
#   'phone': '+16466783136',
#   'rating': 4.5,
#   'review_count': 14,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/mekong-new-york-2?adjust_creative=0eXIew5caAsZxoB9drIq4g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0eXIew5caAsZxoB9drIq4g'}]

# %%
def get_business_review(api_key,business_id):
    import json
    import requests
    business_path = BUSINESS_PATH + business_id+"/reviews"
    url = API_HOST + business_path

    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }


    response = requests.request('GET', url, headers=headers).json()
   
    review_text = ''
    for review in response['reviews']:
        review_text += review['text']
    return review_text

# %%
get_business_review(API_KEY,'flat-top-new-york')
# Out:
# "We made a preshow reservation for Friday at 6 pm, and definitely didn't need it, though the place was hopping by 7.\n\nThey dealt admirably with our picky...A friend who goes to Columbia and lives around the block recommended Flat Top to me, and it didn't dissapoint!\n\nWe sat at the bar and the bartender was...Flat Top is a great example of why you don't go to white-owned restaurants in black neighborhoods. Overpriced, overhyped and ultimately unappetizing...."

# %% [markdown]
# <h4>Finally, put all this together to get review data for the set of restaurants</h4>

# %%
def get_reviews(location,number=15):

    restaurants = get_restaurants(API_KEY,location,number)

    if not restaurants:
        return None
    review_list = list()
    for restaurant in restaurants:
        restaurant_name = restaurant['name']
        restaurant_id = restaurant['id']
        review_text = get_business_review(API_KEY,restaurant_id)
        
        review_list.append((restaurant_name,review_text))
    return review_list

# %%
all_snippets = get_reviews("Columbia University, New York, NY")

# %%
all_snippets
# Out:
# [('Flat Top',
#   "We made a preshow reservation for Friday at 6 pm, and definitely didn't need it, though the place was hopping by 7.\n\nThey dealt admirably with our picky...A friend who goes to Columbia and lives around the block recommended Flat Top to me, and it didn't dissapoint!\n\nWe sat at the bar and the bartender was...Flat Top is a great example of why you don't go to white-owned restaurants in black neighborhoods. Overpriced, overhyped and ultimately unappetizing...."),
#  ('Dun Huang',
#   "I came here after class with a friend and we shared four dishes (I came to taste he came to eat) we tried three Cold noodle dishes: spicy noodle, orange...Came here on a rainy night and the restaurant was busy. Many of the items on the menu looked spicy and we don't have a high tolerance with spice so we both...Food was wonderful, we ordered the traditional Lanzhou noodles, the mung bean jelly, and the lamb kebab (delicious, with just the right touch of fattiness..."),
#  ("e's BAR",
#   "I have been a big fan of e's BAR on Amsterdam since it opened and was excited to hear that they opened a new location by Columbia. The space is all new but...If you want to order on one of many glaring computer screens with no descriptions of the food or drink items instead of interacting with an actual person,...It's always great to have another fun & different place to go for drinks in the neighborhood. Happy to see E's in MoHi!"),
#  ("Lolo's Seafood Shack",
#   "Highly recommend for a night alone or with someone you know well... things will get messy. In a good way. \n\nI go for their boils, because I'm addicted. The...I came here on Saturday afternoon by myself. I chose to eat outside. It was a little breezy due to it be a cold fall. I love the decor. The decor gives me a...I ordered 6 things off of the menu for delivery (uber eats) . \n\nPom Pom shrimp and fries basket - pretty good, shrimp was well-seasoned and a good size (but..."),
#  ('Thai Market',
#   "I'm torn! On one hand I think this place has such tasty food (consistently so!) and excellent vibes, but on the other hand, for the first time in my life I...Was craving Thai food and was close to this neighborhood. Thai Market was really busy when I arrived. No seats available but was able to sit at the bar. I...Great price and value! \nBut it's more like a Thai food for non-thais though. Not very authentic taste. \n\nI ordered Chicken Basil and Somtum for lunch..."),
#  ("Friedman's",
#   "Good food, but took a while for the food to come out. Came here on a Saturday evening and the restaurant was probably around half full. \nI ordered the...[Spanish below] Nice but expressive relative to what they offer. They don't have much options. The burger is 19 dollars for example. \n\nLindo pero muy caro...First time visiting this establishment. Very quaint, and a good value for the food. Really enjoyed it for a brunch with my friend. Food was quick and order..."),
#  ('Saiguette',
#   "This is my favorite place to get bahn-mi in New York. The price is reasonable, the portion size is great, and the sandwiches are packed with flavors. They...I agree with Wendy H.'s review. Strongly. I got Pho here so I can't speak for the bahn mi (maybe their bahn mi is really good?) and I think this is a fine...Service 5/5\nStaff 5/5\nFood 4.5/5\nPrice 3.5/5\nGood atmosphere and food. I Recommend noodles with grilled chicken"),
#  ('Dig Inn',
#   "Dig Inn is popular around here. I didn't know there were so many around. There aren't quite as many as Pret A Manger. Once eating at one, you have pretty...They no longer serve kale\n\nI asked I think it's permanently off the menu\n\nI don't think the food is as fresh as it used to be \nNeed to be wary.I've ordered from this place many times via UberEats. So this review is strictly for the food, and not the ambient of the restaurant.\nIf you ask anyone that..."),
#  ('Mokja',
#   'Well, this was a pleasant surprise! What was more surprising is that I believe Mokja has been in this location for 2+ years and I never realized it....Mokja offers an inviting, clean space for diners. While the list from their menu is simple and easy to order--with a fast and efficient customer...I went here by myself for dinner. I had dumplings, stone pot bibimbap with bulgogi, and hot tea. The service was fine - fast and responsive! \n\nI really love...'),
#  ('Jin Ramen - West Harlem',
#   "Holy Smokes this place is delicious.  \n\nDo yourself a favor and get to west harlem asap for this spot.  The Spicy Tonkotsu Ramen is off the chain! -...Absolutely delicious! Everything we had was super fresh and tasty. Service was excellent. Our 3 year old was also very happy and ate all of his noodles. Do...Jin Ramen is hands down one of the most delicious ramen restaurants I have ever been to. I've been to this establishment several times and I highly..."),
#  ('Marlow Bistro',
#   "I went here for brunch on a Sunday. I loved the decor, elegant but still very warm and inviting. It is right by the Columbia undergrad campus, but the...Hands down best Italian pizza I've had in nyc, and I've tried quite a few places, including the supposedly authentic Eataly, but nothing comes close to the...Reall good dish #Nicoise, well cooked tuna and potatoes! I got two pieces of tuna but my friends just got one and don't know why hhh\nI actually like the..."),
#  ('Pisticci',
#   'While it appears from the street to be a small, Italian restaurant, Pisticci actually has a large back room with plenty of seating for large parties. We...The Fettuccine al Funghi with truffle oil and the Coconut cake are both OMG-delicious and to die for. The tiramisu is a meh. The wine the waitress...We went to Pisticci as a group of 6, and they were very accommodating of our last minute change in reservation time. The server was very kind though not...'),
#  ('Red Hot Hot Pot',
#   "Service; so good! We went at lunch time and the waiter was very attentive and met all our needs.\nHe was very kind and polite!\n\nVibe: super spacious, casual...It is nice to say that I find a place to have good hot pot in Harlem.\n\nMultiple choices of meat and vegetables are provided. Self serving style for sauces....Was really excited to find a hot pot place in the neighborhood again after the one that was on 98th shut down last year. I'm not sure if this place is the..."),
#  ('KALBI',
#   "Great food truck. Their bugogi beef is amazing: well-seasoned, flavorful and does not have excess fat. I ask for extra seasoning (creamy russian) and mix it...Nice taste, good portion, good quality for the price. I do think their bulgogi is too sweet to my taste, but it's still quite delish. The line can move slow...Solid Korean comfort food in a truck conveniently parked by Columbia University campus. It's great to have quick Korean food in the area! The guys who run..."),
#  ('Mekong',
#   "This place is really good! It recently opened and has only been around about two weeks. This spot used to be a strictly Thai restaurant and now it's got a...I came here for the Vietnamese cuisine since I'm always on the search for Vietnamese food in New York City. My wife had the Pho Tai and I had the Pork Chop...This place is gem. We were touring Columbia and needed a place to eat before heading back downtown to work and home. It turned out to be a cooler day and we...")]

# %% [markdown]
# <h2>A function that analyzes emotions</h2>

# %%
def get_nrc_data():
    nrc = "/Users/hardeepjohar/Documents/Courses/Fall2018/data/NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt"
    count=0
    emotion_dict=dict()
    with open(nrc,'r') as f:
        all_lines = list()
        for line in f:
            if count < 46:
                count+=1
                continue
            line = line.strip().split('\t')
            if int(line[2]) == 1:
                if emotion_dict.get(line[0]):
                    emotion_dict[line[0]].append(line[1])
                else:
                    emotion_dict[line[0]] = [line[1]]
    return emotion_dict


def emotion_analyzer(text,emotion_dict=get_nrc_data()):
    #Set up the result dictionary
    emotions = {x for y in emotion_dict.values() for x in y}
    emotion_count = dict()
    for emotion in emotions:
        emotion_count[emotion] = 0

    #Analyze the text and normalize by total number of words
    total_words = len(text.split())
    for word in text.split():
        if emotion_dict.get(word):
            for emotion in emotion_dict.get(word):
                emotion_count[emotion] += 1/len(text.split())
    return emotion_count

# %%
print("%-12s %1s\t%1s %1s %1s %1s   %1s %1s %1s %1s"%(
        "restaurant","fear","trust","negative","positive","joy","disgust","anticip",
        "sadness","surprise"))
        
for snippet in all_snippets:
    text = snippet[1]
    result = emotion_analyzer(text)
    print("%-12s %1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f"%(
        snippet[0][0:10],result['fear'],result['trust'],
          result['negative'],result['positive'],result['joy'],result['disgust'],
          result['anticipation'],result['sadness'],result['surprise']))
# Out:
# restaurant   fear	trust negative positive joy   disgust anticip sadness surprise
# Flat Top     0.00	0.03	0.01	0.03	0.01	0.00	0.01	0.01	0.00
# Dun Huang    0.00	0.02	0.00	0.05	0.02	0.00	0.00	0.01	0.00
# e's BAR      0.00	0.02	0.01	0.05	0.04	0.00	0.02	0.00	0.01
# Lolo's Sea   0.00	0.04	0.01	0.08	0.04	0.00	0.04	0.00	0.02
# Thai Marke   0.00	0.06	0.00	0.07	0.06	0.00	0.02	0.00	0.00
# Friedman's   0.00	0.04	0.00	0.02	0.02	0.00	0.02	0.00	0.01
# Saiguette    0.01	0.01	0.00	0.03	0.01	0.00	0.00	0.00	0.00
# Dig Inn      0.00	0.02	0.01	0.01	0.01	0.00	0.00	0.00	0.00
# Mokja        0.00	0.04	0.01	0.04	0.03	0.00	0.03	0.00	0.03
# Jin Ramen    0.00	0.01	0.00	0.02	0.02	0.00	0.01	0.00	0.00
# Marlow Bis   0.00	0.02	0.00	0.05	0.04	0.00	0.01	0.00	0.01
# Pisticci     0.02	0.01	0.01	0.01	0.01	0.00	0.00	0.01	0.00
# Red Hot Ho   0.00	0.04	0.00	0.04	0.03	0.00	0.04	0.00	0.02
# KALBI        0.00	0.10	0.01	0.10	0.09	0.00	0.05	0.00	0.04
# Mekong       0.00	0.01	0.00	0.02	0.01	0.00	0.00	0.00	0.00

# %% [markdown]
# <h4>Let's functionalize this</h4>
# <h3>For easy of analysis, we'll do the following:</h3>
# <li>generalize it so that we can analyze any document type, not just restaurant reviews
# <li>output a dataframe containing the results. this will make analysis of the results easier
# <li>we'll decide whether or not we should print the output from the function

# %%
def comparative_emotion_analyzer(text_tuples,object_name="Restaurant",print_output=False):
    if print_output:
        print("%-20s %1s\t%1s %1s %1s %1s   %1s %1s %1s %1s"%(object_name,
                                                              "fear","trust","negative","positive",
                                                              "joy","disgust","anticip", "sadness",
                                                              "surprise"))
    import pandas as pd
    df = pd.DataFrame(columns=[object_name,'Fear','Trust','Negative',
                           'Positive','Joy','Disgust','Anticipation',
                           'Sadness','Surprise'],)
    df.set_index(object_name,inplace=True)
    
    output = df    
    for text_tuple in text_tuples:
        text = text_tuple[1] 
        result = emotion_analyzer(text)
        if print_output:
            print("%-20s %1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f"%(
                text_tuple[1][0:20],result['fear'],result['trust'],
                  result['negative'],result['positive'],result['joy'],result['disgust'],
                  result['anticipation'],result['sadness'],result['surprise']))
        df.loc[text_tuple[0]] = [result['fear'],result['trust'],
                  result['negative'],result['positive'],result['joy'],result['disgust'],
                  result['anticipation'],result['sadness'],result['surprise']]
    return output
#And test it        
comparative_emotion_analyzer(all_snippets)
# Out:
#                              Fear     Trust  Negative  Positive       Joy  \
# Restaurant
# Flat Top                 0.000000  0.025974  0.012987  0.025974  0.012987
# Dun Huang                0.000000  0.023529  0.000000  0.047059  0.023529
# e's BAR                  0.000000  0.024390  0.012195  0.048780  0.036585
# Lolo's Seafood Shack     0.000000  0.043956  0.010989  0.076923  0.043956
# Thai Market              0.000000  0.058824  0.000000  0.070588  0.058824
# Friedman's               0.000000  0.037037  0.000000  0.024691  0.024691
# Saiguette                0.012987  0.012987  0.000000  0.025974  0.012987
# Dig Inn                  0.000000  0.022727  0.011364  0.011364  0.011364
# Mokja                    0.000000  0.037500  0.012500  0.037500  0.025000
# Jin Ramen - West Harlem  0.000000  0.012346  0.000000  0.024691  0.024691
# Marlow Bistro            0.000000  0.023810  0.000000  0.047619  0.035714
# Pisticci                 0.024691  0.012346  0.012346  0.012346  0.012346
# Red Hot Hot Pot          0.000000  0.044944  0.000000  0.044944  0.033708
# KALBI                    0.000000  0.098765  0.012346  0.098765  0.086420
# Mekong                   0.000000  0.010870  0.000000  0.021739  0.010870
#
#                          Disgust  Anticipation   Sadness  Surprise
# Restaurant
# Flat Top                     0.0      0.012987  0.012987  0.000000
# Dun Huang                    0.0      0.000000  0.011765  0.000000
# e's BAR                      0.0      0.024390  0.000000  0.012195
# Lolo's Seafood Shack         0.0      0.043956  0.000000  0.021978
# Thai Market                  0.0      0.023529  0.000000  0.000000
# Friedman's                   0.0      0.024691  0.000000  0.012346
# Saiguette                    0.0      0.000000  0.000000  0.000000
# Dig Inn                      0.0      0.000000  0.000000  0.000000
# Mokja                        0.0      0.025000  0.000000  0.025000
# Jin Ramen - West Harlem      0.0      0.012346  0.000000  0.000000
# Marlow Bistro                0.0      0.011905  0.000000  0.011905
# Pisticci                     0.0      0.000000  0.012346  0.000000
# Red Hot Hot Pot              0.0      0.044944  0.000000  0.022472
# KALBI                        0.0      0.049383  0.000000  0.037037
# Mekong                       0.0      0.000000  0.000000  0.000000

# %%
def analyze_nearby_restaurants(address,number=15):
    snippets = get_reviews(address,number)
    return comparative_emotion_analyzer(snippets)

#And test it    
analyze_nearby_restaurants("Columbia University",15)
# Out:
#                              Fear     Trust  Negative  Positive       Joy  \
# Restaurant
# Flat Top                 0.000000  0.025974  0.012987  0.025974  0.012987
# Dun Huang                0.000000  0.023529  0.000000  0.047059  0.023529
# e's BAR                  0.000000  0.024390  0.012195  0.048780  0.036585
# Lolo's Seafood Shack     0.000000  0.043956  0.010989  0.076923  0.043956
# Thai Market              0.000000  0.058824  0.000000  0.070588  0.058824
# Friedman's               0.000000  0.037037  0.000000  0.024691  0.024691
# Saiguette                0.012987  0.012987  0.000000  0.025974  0.012987
# Dig Inn                  0.000000  0.022727  0.011364  0.011364  0.011364
# Mokja                    0.000000  0.037500  0.012500  0.037500  0.025000
# Jin Ramen - West Harlem  0.000000  0.012346  0.000000  0.024691  0.024691
# Marlow Bistro            0.000000  0.023810  0.000000  0.047619  0.035714
# Pisticci                 0.024691  0.012346  0.012346  0.012346  0.012346
# Red Hot Hot Pot          0.000000  0.044944  0.000000  0.044944  0.033708
# KALBI                    0.000000  0.098765  0.012346  0.098765  0.086420
# Mekong                   0.000000  0.010870  0.000000  0.021739  0.010870
#
#                          Disgust  Anticipation   Sadness  Surprise
# Restaurant
# Flat Top                     0.0      0.012987  0.012987  0.000000
# Dun Huang                    0.0      0.000000  0.011765  0.000000
# e's BAR                      0.0      0.024390  0.000000  0.012195
# Lolo's Seafood Shack         0.0      0.043956  0.000000  0.021978
# Thai Market                  0.0      0.023529  0.000000  0.000000
# Friedman's                   0.0      0.024691  0.000000  0.012346
# Saiguette                    0.0      0.000000  0.000000  0.000000
# Dig Inn                      0.0      0.000000  0.000000  0.000000
# Mokja                        0.0      0.025000  0.000000  0.025000
# Jin Ramen - West Harlem      0.0      0.012346  0.000000  0.000000
# Marlow Bistro                0.0      0.011905  0.000000  0.011905
# Pisticci                     0.0      0.000000  0.012346  0.000000
# Red Hot Hot Pot              0.0      0.044944  0.000000  0.022472
# KALBI                        0.0      0.049383  0.000000  0.037037
# Mekong                       0.0      0.000000  0.000000  0.000000

# %%
#Test it on some other place
analyze_nearby_restaurants("221 Baker Street, London, UK",15)
# Out:
#                          Fear     Trust  Negative  Positive       Joy  \
# Restaurant
# Ffiona's Restaurant  0.011628  0.023256  0.023256  0.058140  0.034884
# The Grazing Goat     0.000000  0.000000  0.000000  0.024691  0.000000
# The Mayfair Chippy   0.000000  0.058140  0.000000  0.069767  0.034884
# The Victoria         0.000000  0.023810  0.000000  0.059524  0.035714
# Dishoom              0.021978  0.043956  0.054945  0.043956  0.043956
# Great Queen Street   0.025000  0.000000  0.025000  0.050000  0.012500
# Mother Mash          0.000000  0.000000  0.000000  0.036145  0.012048
# Nambu Tei            0.013158  0.039474  0.000000  0.052632  0.052632
# The Pig and Butcher  0.000000  0.011364  0.000000  0.045455  0.022727
# Flat Iron            0.000000  0.024390  0.000000  0.024390  0.012195
# Hook                 0.000000  0.033708  0.022472  0.067416  0.033708
# The Fat Bear         0.011905  0.023810  0.000000  0.035714  0.023810
# Honey & Co           0.000000  0.012987  0.000000  0.025974  0.012987
# Bamboo Flute         0.000000  0.035294  0.011765  0.070588  0.047059
# Burger & Lobster     0.000000  0.000000  0.000000  0.023256  0.000000
#
#                       Disgust  Anticipation   Sadness  Surprise
# Restaurant
# Ffiona's Restaurant  0.000000      0.011628  0.023256  0.023256
# The Grazing Goat     0.000000      0.012346  0.000000  0.012346
# The Mayfair Chippy   0.011628      0.023256  0.000000  0.034884
# The Victoria         0.000000      0.000000  0.000000  0.000000
# Dishoom              0.010989      0.043956  0.010989  0.010989
# Great Queen Street   0.000000      0.012500  0.012500  0.012500
# Mother Mash          0.000000      0.000000  0.000000  0.000000
# Nambu Tei            0.000000      0.026316  0.013158  0.026316
# The Pig and Butcher  0.000000      0.011364  0.011364  0.011364
# Flat Iron            0.000000      0.024390  0.000000  0.000000
# Hook                 0.011236      0.033708  0.011236  0.033708
# The Fat Bear         0.011905      0.035714  0.000000  0.023810
# Honey & Co           0.000000      0.000000  0.000000  0.000000
# Bamboo Flute         0.000000      0.058824  0.011765  0.035294
# Burger & Lobster     0.000000      0.000000  0.000000  0.000000
